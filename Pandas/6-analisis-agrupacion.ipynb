# %% [markdown]
# # Análisis - Agrupación
# ## Groupby

# %%
import pandas as pd
pd.set_option('display.max_columns', None) # Ver todas las columnas [2]
pd.set_option('display.width', 1000)      # Ajustar ancho de visualización

# %%
path = "../Pandas/datasets/Online_Retail.csv"

df = pd.read_csv(path, encoding="latin-1")
df.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity   InvoiceDate  UnitPrice  CustomerID         Country
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6  12/1/10 8:26       2.55     17850.0  United Kingdom
# 1    536365     71053                 WHITE METAL LANTERN         6  12/1/10 8:26       3.39     17850.0  United Kingdom
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8  12/1/10 8:26       2.75     17850.0  United Kingdom

# %%
# Usando value_counts: ESte lo que hace es ir contando cada uno de las características que se repiten
country_count = df['Country'].value_counts()
print(country_count)
# Out:
# Country
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
# Vamos a hacer un agrupamiento por país pero para calcular la cantidad
country_group = df.groupby('Country')['Quantity'].sum()
country_group_unitprice = df.groupby('Country')['UnitPrice'].sum()
print(country_group)
# Out:
# Country
# Australia                 83653
# Austria                    4827
# Bahrain                     260
# Belgium                   23152
# Brazil                      356
# Canada                     2763
# Channel Islands            9479
# Cyprus                     6317
# Czech Republic              592
# Denmark                    8188
# EIRE                     142637
# European Community          497
# Finland                   10666
# France                   110480
# Germany                  117448
# Greece                     1556
# Hong Kong                  4769
# Iceland                    2458
# Israel                     4353
# Italy                      7999
# Japan                     25218
# Lebanon                     386
# Lithuania                   652
# Malta                       944
# Netherlands              200128
# Norway                    19247
# Poland                     3653
# Portugal                  16180
# RSA                         352
# ...

# %%
country_stats = df.groupby('Country')['UnitPrice'].agg(['mean', 'sum'])
print(country_stats)
# Out:
#                             mean          sum
# Country
# Australia               3.220612     4054.750
# Austria                 4.243192     1701.520
# Bahrain                 4.556316       86.570
# Belgium                 3.644335     7540.130
# Brazil                  4.456250      142.600
# Canada                  6.030331      910.580
# Channel Islands         4.932124     3738.550
# Cyprus                  6.302363     3920.070
# Czech Republic          2.938333       88.150
# Denmark                 3.256941     1266.950
# EIRE                    5.911077    48447.190
# European Community      4.820492      294.050
# Finland                 5.448705     3786.850
# France                  5.028864    43031.990
# Germany                 3.966930    37666.000
# Greece                  4.885548      713.290
# Hong Kong              42.505208    12241.500
# Iceland                 2.644011      481.210
# Israel                  3.633131     1079.040
# ...

# %%
country_stock_group = df.groupby(['Country', 'StockCode'])['Quantity'].sum()
print(country_stock_group)
# Out:
# Country      StockCode
# Australia    15036        600
#              15056BL        3
#              16161P       400
#              16169E        25
#              20665          6
#                          ...
# Unspecified  85180A         2
#              85180B         1
#              85212         12
#              85213         12
#              85227         10
# Name: Quantity, Length: 19839, dtype: int64

# %%
def total_revenue(group):
  return (group['Quantity'] * group['UnitPrice']).sum()


revenue_per_country = df.groupby('Country').apply(total_revenue)
print(revenue_per_country)
# Out:
# Country
# Australia                137077.270
# Austria                   10154.320
# Bahrain                     548.400
# Belgium                   40910.960
# Brazil                     1143.600
# Canada                     3666.380
# Channel Islands           20086.290
# Cyprus                    12946.290
# Czech Republic              707.720
# Denmark                   18768.140
# EIRE                     263276.820
# European Community         1291.750
# Finland                   22326.740
# France                   197403.900
# Germany                  221698.210
# Greece                     4710.520
# Hong Kong                 10117.040
# Iceland                    4310.000
# Israel                     7907.820
# Italy                     16890.510
# Japan                     35340.620
# Lebanon                    1693.880
# Lithuania                  1661.060
# Malta                      2505.470
# Netherlands              284661.540
# Norway                    35163.460
# ...

# %%
order_revenue_per_country = revenue_per_country.sort_values(ascending=False)

top3_best = order_revenue_per_country.iloc[:3]
print("Los 3 países con menores ventas: últimos en el ranking:\n",top3_best)

top3_worst = order_revenue_per_country.iloc[-3:]
print("Los 3 países con menores ventas: últimos en el ranking:\n", top3_worst)
# Out:
# Los 3 países con menores ventas: últimos en el ranking:
#  Country
# United Kingdom    8187806.364
# Netherlands        284661.540
# EIRE               263276.820
# dtype: float64
# Los 3 países con menores ventas: últimos en el ranking:
#  Country
# Czech Republic    707.72
# Bahrain           548.40
# Saudi Arabia      131.17
# dtype: float64
